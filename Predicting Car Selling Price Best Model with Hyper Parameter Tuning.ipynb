# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
df=pd.read_csv('F:/Data_Science/car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df.count()
# Out:
# Car_Name         301
# Year             301
# Selling_Price    301
# Present_Price    301
# Kms_Driven       301
# Fuel_Type        301
# Seller_Type      301
# Transmission     301
# Owner            301
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
print(df['Seller_Type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.drop('Car_Name',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
df['Current Year']=2020

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year
# 0       Manual      0          2020
# 1       Manual      0          2020
# 2       Manual      0          2020
# 3       Manual      0          2020
# 4       Manual      0          2020

# %%
df['No_Year']=df['Current Year']- df['Year']

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  No_Year
# 0       Manual      0          2020        6
# 1       Manual      0          2020        7
# 2       Manual      0          2020        3
# 3       Manual      0          2020        9
# 4       Manual      0          2020        6

# %%
df.drop('Year',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  No_Year
# 0       Manual      0          2020        6
# 1       Manual      0          2020        7
# 2       Manual      0          2020        3
# 3       Manual      0          2020        9
# 4       Manual      0          2020        6

# %%
df['Fuel_Type'].value_counts()
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
sns.catplot(x='Fuel_Type', y='Selling_Price', data=df.sort_values('Selling_Price',ascending=False),kind='boxen',height=4,aspect=3)
plt.show()

# %%
Fuel_Type=df['Fuel_Type']
Fuel_Type=pd.get_dummies(Fuel_Type,drop_first=True)

# %%
Seller_Type=df['Seller_Type']
Seller_Type=pd.get_dummies(Seller_Type,drop_first=True)

# %%
Transmission=df['Transmission']
Transmission=pd.get_dummies(Transmission,drop_first=True)

# %%
df=pd.concat([df,Fuel_Type,Seller_Type,Transmission],axis=1)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current Year  No_Year  Diesel  Petrol  Individual  \
# ...

# %%
df.drop(['Fuel_Type','Seller_Type','Transmission'],axis=1,inplace=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Current Year  No_Year  \
# 0             3.35           5.59       27000      0          2020        6
# 1             4.75           9.54       43000      0          2020        7
# 2             7.25           9.85        6900      0          2020        3
# 3             2.85           4.15        5200      0          2020        9
# 4             4.60           6.87       42450      0          2020        6
# ..             ...            ...         ...    ...           ...      ...
# 296           9.50          11.60       33988      0          2020        4
# 297           4.00           5.90       60000      0          2020        5
# 298           3.35          11.00       87934      0          2020       11
# 299          11.50          12.50        9000      0          2020        3
# 300           5.30           5.90        5464      0          2020        4
#
#      Diesel  Petrol  Individual  Manual
# ...

# %%
df.drop('Current Year',axis=1,inplace=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  No_Year  Diesel  Petrol  \
# 0             3.35           5.59       27000      0        6       0       1
# 1             4.75           9.54       43000      0        7       1       0
# 2             7.25           9.85        6900      0        3       0       1
# 3             2.85           4.15        5200      0        9       0       1
# 4             4.60           6.87       42450      0        6       1       0
# ..             ...            ...         ...    ...      ...     ...     ...
# 296           9.50          11.60       33988      0        4       1       0
# 297           4.00           5.90       60000      0        5       0       1
# 298           3.35          11.00       87934      0       11       0       1
# 299          11.50          12.50        9000      0        3       1       0
# 300           5.30           5.90        5464      0        4       0       1
#
#      Individual  Manual
# ...

# %%
df.corr()
# Out:
#                Selling_Price  Present_Price  Kms_Driven     Owner   No_Year  \
# Selling_Price       1.000000       0.878983    0.029187 -0.088344 -0.236141
# Present_Price       0.878983       1.000000    0.203647  0.008057  0.047584
# Kms_Driven          0.029187       0.203647    1.000000  0.089216  0.524342
# Owner              -0.088344       0.008057    0.089216  1.000000  0.182104
# No_Year            -0.236141       0.047584    0.524342  0.182104  1.000000
# Diesel              0.552339       0.473306    0.172515 -0.053469 -0.064315
# Petrol             -0.540571      -0.465244   -0.172874  0.055687  0.059959
# Individual         -0.550724      -0.512030   -0.101419  0.124269  0.039896
# Manual             -0.367128      -0.348715   -0.162510 -0.050316 -0.000394
#
#                  Diesel    Petrol  Individual    Manual
# Selling_Price  0.552339 -0.540571   -0.550724 -0.367128
# Present_Price  0.473306 -0.465244   -0.512030 -0.348715
# ...

# %%
#get correlations of each features in dataset
#corrmap = df.corr()
#top_corr_features=corrmap.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df.corr(),annot=True,cmap="RdYlGn")

# %%
df1=df

# %%
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  No_Year  Diesel  Petrol  \
# 0             3.35           5.59       27000      0        6       0       1
# 1             4.75           9.54       43000      0        7       1       0
# 2             7.25           9.85        6900      0        3       0       1
# 3             2.85           4.15        5200      0        9       0       1
# 4             4.60           6.87       42450      0        6       1       0
# ..             ...            ...         ...    ...      ...     ...     ...
# 296           9.50          11.60       33988      0        4       1       0
# 297           4.00           5.90       60000      0        5       0       1
# 298           3.35          11.00       87934      0       11       0       1
# 299          11.50          12.50        9000      0        3       1       0
# 300           5.30           5.90        5464      0        4       0       1
#
#      Individual  Manual
# ...

# %%
df1=df1.loc[:,~df1.columns.duplicated()]

# %%
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  No_Year  Diesel  Petrol  \
# 0             3.35           5.59       27000      0        6       0       1
# 1             4.75           9.54       43000      0        7       1       0
# 2             7.25           9.85        6900      0        3       0       1
# 3             2.85           4.15        5200      0        9       0       1
# 4             4.60           6.87       42450      0        6       1       0
# ..             ...            ...         ...    ...      ...     ...     ...
# 296           9.50          11.60       33988      0        4       1       0
# 297           4.00           5.90       60000      0        5       0       1
# 298           3.35          11.00       87934      0       11       0       1
# 299          11.50          12.50        9000      0        3       1       0
# 300           5.30           5.90        5464      0        4       0       1
#
#      Individual  Manual
# ...

# %%
X=df1.iloc[:,1:]

# %%
X
# Out:
#      Present_Price  Kms_Driven  Owner  No_Year  Diesel  Petrol  Individual  \
# 0             5.59       27000      0        6       0       1           0
# 1             9.54       43000      0        7       1       0           0
# 2             9.85        6900      0        3       0       1           0
# 3             4.15        5200      0        9       0       1           0
# 4             6.87       42450      0        6       1       0           0
# ..             ...         ...    ...      ...     ...     ...         ...
# 296          11.60       33988      0        4       1       0           0
# 297           5.90       60000      0        5       0       1           0
# 298          11.00       87934      0       11       0       1           0
# 299          12.50        9000      0        3       1       0           0
# 300           5.90        5464      0        4       0       1           0
#
#      Manual
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
y=df1.iloc[:,0]

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [3.81760745e-01 4.06734659e-02 3.37745932e-04 7.37357062e-02
#  2.17834651e-01 2.19851933e-02 1.21076145e-01 1.42596348e-01]

# %%
features_important=pd.Series(model.feature_importances_,index=X.columns)
features_important.sort_values(ascending=False).head(6).plot(kind='barh')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=10)

# %%
s=StandardScaler()
X_train=s.fit_transform(X_train)
X_test=s.transform(X_test)

# %%
rf_reg=RandomForestRegressor()
rf_reg.fit(X_train,y_train)
rf_reg.score(X_test,y_test)
# Out:
# 0.9285127189650595

# %%
from sklearn.model_selection import ShuffleSplit
cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=10)
cross_val_score(rf_reg,X,y,cv=cv).mean()
# Out:
# 0.8908711783865119

# %% [markdown]
# # Check for Other Models

# %%
def cross_val_score_model(model):
    cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=10)
    cv_score=cross_val_score(model,X,y,cv=cv).mean()
    print('CV_Score' + ' '+ str(model) +': '+ str(cv_score))

cross_val_score_model(RandomForestRegressor())
cross_val_score_model(LinearRegression())
cross_val_score_model(Lasso())
# Out:
# CV_Score RandomForestRegressor(): 0.8903001279126128
# CV_Score LinearRegression(): 0.8393492352483254
# CV_Score Lasso(): 0.8062645818078874

# %% [markdown]
# # Best Model: RandomForestRegressor

# %% [markdown]
# # HYPER TUNING of RandomForestRegressor

# %%
#Randomized Search CV
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 50, num = 10)]

# %%
# Create the random grid

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth}

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=10)
rf_random = RandomizedSearchCV(estimator = rf_reg, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 20, cv = cv, verbose=2, n_jobs = 1)
rf_random.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] n_estimators=300, max_features=auto, max_depth=45 ...............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=300, max_features=auto, max_depth=45, total=   0.9s
# [CV] n_estimators=300, max_features=auto, max_depth=45 ...............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  n_estimators=300, max_features=auto, max_depth=45, total=   0.9s
# [CV] n_estimators=300, max_features=auto, max_depth=45 ...............
# [CV]  n_estimators=300, max_features=auto, max_depth=45, total=   0.9s
# [CV] n_estimators=300, max_features=auto, max_depth=45 ...............
# [CV]  n_estimators=300, max_features=auto, max_depth=45, total=   1.0s
# [CV] n_estimators=300, max_features=auto, max_depth=45 ...............
# [CV]  n_estimators=300, max_features=auto, max_depth=45, total=   0.9s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 600, 'max_features': 'auto', 'max_depth': 30}

# %%
cross_val_score_model(RandomForestRegressor(n_estimators=600, max_features='auto', max_depth=30))
# Out:
# CV_Score RandomForestRegressor(max_depth=30, n_estimators=600): 0.8929514357772899

# %% [markdown]
# # BEST MODEL : 'RANDOM FOREST REGRESSOR' WITH HYPER PARAMETER TUNING

# %%
rf_reg_best=RandomForestRegressor(n_estimators=600, max_features='auto', max_depth=30)
rf_reg_best.fit(X_train,y_train)
rf_reg_best.score(X_test,y_test)
# Out:
# 0.9279553639952175

# %%
df.iloc[251]
# Out:
# Selling_Price        5.0
# Present_Price        9.9
# Kms_Driven       56701.0
# Owner                0.0
# No_Year              7.0
# Diesel               0.0
# Petrol               1.0
# Individual           0.0
# Manual               1.0
# Name: 251, dtype: float64

# %% [markdown]
# # Predicting car Prize with RandomForestRegressor without Hyper Tuning Parameter

# %%
a=[[9.9,56701,0,7,0,1,0,1]]
a=s.transform(a)
b=rf_reg.predict(a)
b
# Out:
# array([5.1537])

# %% [markdown]
# # Predicting car Prize with RandomForestRegressor with Hyper Tuning Parameter

# %%
a=[[9.9,56701,0,7,0,1,0,1]]
a=s.transform(a)
b=rf_reg_best.predict(a)
b
# Out:
# array([5.13315])
